# %% [markdown]
#  # The purpose of this project was to practice SQL

# %% [markdown]
# **SQL** stands for **Structured Query Language** and it is an ANSI standard computer language for accessing and manipulating database systems. It is used for managing data in relational database management system which stores data in the form of tables and relationship between data is also stored in the form of tables. **SQL** statements are used to retrieve and update data in a database

# %%
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')

# %%
import os

# Print the contents of the working directory
print(os.listdir("/kaggle/working/"))
# Out:
# []

# %% [markdown]
# # SQL Retrieving Data from Tables

# %%
pd.read_sql(""" SELECT *
                FROM sqlite_master
                WHERE type='table';""",
           conn)
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %%
pd.read_sql("""SELECT *
               FROM Indicators
               LIMIT 10;""",
           conn)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
# 5  Arab World         ARB        Arms imports (SIPRI trend indicator values)
# 6  Arab World         ARB               Birth rate, crude (per 1,000 people)
# 7  Arab World         ARB                                 CO2 emissions (kt)
# 8  Arab World         ARB             CO2 emissions (metric tons per capita)
# 9  Arab World         ARB  CO2 emissions from gaseous fuel consumption (%...
#
#        IndicatorCode  Year         Value
# 0        SP.ADO.TFRT  1960  1.335609e+02
# 1        SP.POP.DPND  1960  8.779760e+01
# 2     SP.POP.DPND.OL  1960  6.634579e+00
# 3     SP.POP.DPND.YG  1960  8.102333e+01
# 4     MS.MIL.XPRT.KD  1960  3.000000e+06
# 5     MS.MIL.MPRT.KD  1960  5.380000e+08
# 6     SP.DYN.CBRT.IN  1960  4.769789e+01
# 7     EN.ATM.CO2E.KT  1960  5.956399e+04
# 8     EN.ATM.CO2E.PC  1960  6.439635e-01
# 9  EN.ATM.CO2E.GF.ZS  1960  5.041292e+00

# %%
pd.read_sql("""SELECT * FROM Country LIMIT 20;""",conn)
# Out:
#    CountryCode            ShortName            TableName  \
# 0          AFG          Afghanistan          Afghanistan
# 1          ALB              Albania              Albania
# 2          DZA              Algeria              Algeria
# 3          ASM       American Samoa       American Samoa
# 4          ADO              Andorra              Andorra
# 5          AGO               Angola               Angola
# 6          ATG  Antigua and Barbuda  Antigua and Barbuda
# 7          ARB           Arab World           Arab World
# 8          ARG            Argentina            Argentina
# 9          ARM              Armenia              Armenia
# 10         ABW                Aruba                Aruba
# 11         AUS            Australia            Australia
# 12         AUT              Austria              Austria
# 13         AZE           Azerbaijan           Azerbaijan
# 14         BHR              Bahrain              Bahrain
# 15         BGD           Bangladesh           Bangladesh
# 16         BRB             Barbados             Barbados
# 17         BLR              Belarus              Belarus
# 18         BEL              Belgium              Belgium
# 19         BLZ               Belize               Belize
#
#                                    LongName Alpha2Code           CurrencyUnit  \
# 0              Islamic State of Afghanistan         AF         Afghan afghani
# 1                       Republic of Albania         AL           Albanian lek
# 2   People's Democratic Republic of Algeria         DZ         Algerian dinar
# 3                            American Samoa         AS            U.S. dollar
# 4                   Principality of Andorra         AD                   Euro
# 5               People's Republic of Angola         AO         Angolan kwanza
# 6                       Antigua and Barbuda         AG  East Caribbean dollar
# 7                                Arab World         1A
# 8                        Argentine Republic         AR         Argentine peso
# 9                       Republic of Armenia         AM          Armenian dram
# 10                                    Aruba         AW          Aruban florin
# 11                Commonwealth of Australia         AU      Australian dollar
# 12                      Republic of Austria         AT                   Euro
# 13                   Republic of Azerbaijan         AZ        New Azeri manat
# 14                       Kingdom of Bahrain         BH         Bahraini dinar
# 15          People's Republic of Bangladesh         BD       Bangladeshi taka
# 16                                 Barbados         BB        Barbados dollar
# 17                      Republic of Belarus         BY       Belarusian rubel
# 18                       Kingdom of Belgium         BE                   Euro
# 19                                   Belize         BZ          Belize dollar
#
#                                          SpecialNotes  \
# 0   Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
# 5   April 2013 database update: Based on IMF data,...
# 6   April 2012 database update: Based on official ...
# 7   Arab World aggregate. Arab World is composed o...
# 8                  The base year has changed to 2004.
# 9
# 10  SNA data for 2000-2011 are updated from offici...
# 11  Fiscal year end: June 30; reporting period for...
# 12  A simple multiplier is used to convert the nat...
# 13  April 2012 database update: National accounts ...
# 14  Based on official government statistics; the n...
# 15  Fiscal year end: June 30; reporting period for...
# 16
# 17
# 18  A simple multiplier is used to convert the nat...
# 19
#
#                         Region           IncomeGroup Wb2Code  ...  \
# 0                   South Asia            Low income      AF  ...
# 1        Europe & Central Asia   Upper middle income      AL  ...
# 2   Middle East & North Africa   Upper middle income      DZ  ...
# 3          East Asia & Pacific   Upper middle income      AS  ...
# 4        Europe & Central Asia  High income: nonOECD      AD  ...
# 5           Sub-Saharan Africa   Upper middle income      AO  ...
# 6    Latin America & Caribbean  High income: nonOECD      AG  ...
# 7                                                         1A  ...
# 8    Latin America & Caribbean  High income: nonOECD      AR  ...
# 9        Europe & Central Asia   Lower middle income      AM  ...
# 10   Latin America & Caribbean  High income: nonOECD      AW  ...
# 11         East Asia & Pacific     High income: OECD      AU  ...
# 12       Europe & Central Asia     High income: OECD      AT  ...
# 13       Europe & Central Asia   Upper middle income      AZ  ...
# 14  Middle East & North Africa  High income: nonOECD      BH  ...
# 15                  South Asia   Lower middle income      BD  ...
# 16   Latin America & Caribbean  High income: nonOECD      BB  ...
# 17       Europe & Central Asia   Upper middle income      BY  ...
# 18       Europe & Central Asia     High income: OECD      BE  ...
# 19   Latin America & Caribbean   Upper middle income      BZ  ...
#
#         GovernmentAccountingConcept  \
# 0   Consolidated central government
# 1      Budgetary central government
# 2      Budgetary central government
# 3
# 4
# 5      Budgetary central government
# 6      Budgetary central government
# 7
# 8   Consolidated central government
# 9   Consolidated central government
# 10
# 11  Consolidated central government
# 12  Consolidated central government
# 13  Consolidated central government
# 14     Budgetary central government
# 15  Consolidated central government
# 16     Budgetary central government
# 17  Consolidated central government
# 18  Consolidated central government
# 19     Budgetary central government
#
#                   ImfDataDisseminationStandard  \
# 0     General Data Dissemination System (GDDS)
# 1     General Data Dissemination System (GDDS)
# 2     General Data Dissemination System (GDDS)
# 3
# 4
# 5     General Data Dissemination System (GDDS)
# 6     General Data Dissemination System (GDDS)
# 7
# 8   Special Data Dissemination Standard (SDDS)
# 9   Special Data Dissemination Standard (SDDS)
# 10
# 11  Special Data Dissemination Standard (SDDS)
# 12  Special Data Dissemination Standard (SDDS)
# 13    General Data Dissemination System (GDDS)
# 14    General Data Dissemination System (GDDS)
# 15    General Data Dissemination System (GDDS)
# 16    General Data Dissemination System (GDDS)
# 17  Special Data Dissemination Standard (SDDS)
# 18  Special Data Dissemination Standard (SDDS)
# 19    General Data Dissemination System (GDDS)
#
#                                LatestPopulationCensus  \
# 0                                                1979
# 1                                                2011
# 2                                                2008
# 3                                                2010
# 4   2011. Population data compiled from administra...
# 5                                                2014
# 6                                                2011
# 7
# 8                                                2010
# 9                                                2011
# 10                                               2010
# 11                                               2011
# 12  2011. Population data compiled from administra...
# 13                                               2009
# 14                                               2010
# 15                                               2011
# 16                                               2010
# 17                                               2009
# 18                                               2011
# 19                                               2010
#
#                                 LatestHouseholdSurvey  \
# 0   Multiple Indicator Cluster Survey (MICS), 2010/11
# 1        Demographic and Health Survey (DHS), 2008/09
# 2      Multiple Indicator Cluster Survey (MICS), 2012
# 3
# 4
# 5                Malaria Indicator Survey (MIS), 2011
# 6
# 7
# 8   Multiple Indicator Cluster Survey (MICS), 2011/12
# 9           Demographic and Health Survey (DHS), 2010
# 10
# 11
# 12
# 13          Demographic and Health Survey (DHS), 2006
# 14
# 15  Demographic and Health Survey (DHS), 2014; HIV...
# 16     Multiple Indicator Cluster Survey (MICS), 2012
# 17     Multiple Indicator Cluster Survey (MICS), 2012
# 18
# 19     Multiple Indicator Cluster Survey (MICS), 2011
#
#            SourceOfMostRecentIncomeAndExpenditureData  \
# 0             Integrated household survey (IHS), 2008
# 1   Living Standards Measurement Study Survey (LSM...
# 2             Integrated household survey (IHS), 1995
# 3
# 4
# 5          Integrated household survey (IHS), 2008/09
# 6
# 7
# 8             Integrated household survey (IHS), 2012
# 9             Integrated household survey (IHS), 2012
# 10
# 11     Expenditure survey/budget survey (ES/BS), 2003
# 12            Integrated household survey (IHS), 2004
# 13  Living Standards Measurement Study Survey (LSM...
# 14
# 15            Integrated household survey (IHS), 2010
# 16
# 17            Integrated household survey (IHS), 2013
# 18            Integrated household survey (IHS), 2000
# 19                     Labor force survey (LFS), 1999
#
#    VitalRegistrationComplete              LatestAgriculturalCensus  \
# 0                                                          2013/14
# 1                        Yes                                  2012
# 2
# 3                        Yes                                  2007
# 4                        Yes
# 5                                                             2015
# 6                        Yes                                  2007
# 7
# 8                        Yes                                  2013
# 9                        Yes                               2013/14
# 10                       Yes
# 11                       Yes                                  2011
# 12                       Yes                                  2010
# 13                       Yes                                  2015
# 14                       Yes
# 15                                                            2008
# 16                       Yes  2010. Population and Housing Census.
# 17                       Yes
# 18                       Yes                                  2010
# 19
#
#    LatestIndustrialData LatestTradeData LatestWaterWithdrawalData
# 0                                  2013                      2000
# 1                  2011            2013                      2006
# 2                  2010            2013                      2001
# 3
# 4                                  2006
# 5                                                            2005
# 6                                  2013                      2005
# 7
# 8                  2002            2013                      2011
# 9                  2008            2013                      2012
# 10                                 2012
# 11                 2011            2013                      2000
# 12                 2010            2013                      2002
# 13                 2011            2013                      2012
# 14                 2010            2011                      2003
# 15                                 2007                      2008
# 16                                 2013                      2005
# 17                 2011            2013                      2000
# 18                 2010            2013                      2007
# 19                                 2013                      2000
#
# [20 rows x 31 columns]

# %%
#Displaying 3 numbers in 3 columns
pd.read_sql("""SELECT 5, 10, 15;""",
           conn)
# Out:
#    5  10  15
# 0  5  10  15

# %%
#The sum of 2 numbers
pd.read_sql("""SELECT 55+90;""",
           conn)
# Out:
#    55+90
# 0    145

# %%
#The result of an arithmetic expression
pd.read_sql("""SELECT 10+15-5*2;""",
           conn)
# Out:
#    10+15-5*2
# 0         15

# %%
#Displaying Year and Value
pd.read_sql("""SELECT Year, Value
               FROM Indicators;""",
           conn)
# Out:
#          Year         Value
# 0        1960  1.335609e+02
# 1        1960  8.779760e+01
# 2        1960  6.634579e+00
# 3        1960  8.102333e+01
# 4        1960  3.000000e+06
# ...       ...           ...
# 5656453  2015  3.600000e+01
# 5656454  2015  9.000000e+01
# 5656455  2015  2.420000e+02
# 5656456  2015  3.300000e+00
# 5656457  2015  3.280000e+01
#
# [5656458 rows x 2 columns]

# %%
pd.read_sql("""SELECT CountryName, CountryCode, IndicatorName
               FROM Indicators;""",
           conn)
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# ...             ...         ...
# 5656453    Zimbabwe         ZWE
# 5656454    Zimbabwe         ZWE
# 5656455    Zimbabwe         ZWE
# 5656456    Zimbabwe         ZWE
# 5656457    Zimbabwe         ZWE
#
#                                              IndicatorName
# 0        Adolescent fertility rate (births per 1,000 wo...
# 1        Age dependency ratio (% of working-age populat...
# 2        Age dependency ratio, old (% of working-age po...
# 3        Age dependency ratio, young (% of working-age ...
# 4              Arms exports (SIPRI trend indicator values)
# ...                                                    ...
# 5656453          Time required to register property (days)
# 5656454           Time required to start a business (days)
# 5656455              Time to prepare and pay taxes (hours)
# 5656456                 Time to resolve insolvency (years)
# 5656457           Total tax rate (% of commercial profits)
#
# [5656458 rows x 3 columns]

# %%
#Retrieving the values of CountryName for all countries
pd.read_sql("""SELECT DISTINCT CountryName
               FROM Indicators;""",
           conn)
# Out:
#             CountryName
# 0           Afghanistan
# 1               Albania
# 2               Algeria
# 3        American Samoa
# 4               Andorra
# ..                  ...
# 242  West Bank and Gaza
# 243               World
# 244         Yemen, Rep.
# 245              Zambia
# 246            Zimbabwe
#
# [247 rows x 1 columns]

# %% [markdown]
# # SQL Filtering and Sorting

# %%
#Grouping and counting records by region
pd.read_sql("""SELECT Region, COUNT(*) AS [Count]
               FROM Country 
               GROUP BY Region
               ORDER BY 2 DESC;""",
            conn)
# Out:
#                        Region  Count
# 0       Europe & Central Asia     57
# 1          Sub-Saharan Africa     48
# 2   Latin America & Caribbean     41
# 3         East Asia & Pacific     36
# 4                                 33
# 5  Middle East & North Africa     21
# 6                  South Asia      8
# 7               North America      3

# %%
#Information about Bolivia
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE CountryName = "Bolivia";""",
           conn)
# Out:
#       CountryName CountryCode  \
# 0         Bolivia         BOL
# 1         Bolivia         BOL
# 2         Bolivia         BOL
# 3         Bolivia         BOL
# 4         Bolivia         BOL
# ...           ...         ...
# 35302     Bolivia         BOL
# 35303     Bolivia         BOL
# 35304     Bolivia         BOL
# 35305     Bolivia         BOL
# 35306     Bolivia         BOL
#
#                                            IndicatorName      IndicatorCode  \
# 0      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1      Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2      Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3      Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4            Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# ...                                                  ...                ...
# 35302          Time required to register property (days)        IC.PRP.DURS
# 35303           Time required to start a business (days)        IC.REG.DURS
# 35304              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 35305                 Time to resolve insolvency (years)        IC.ISV.DURS
# 35306           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#        Year         Value
# 0      1960  1.028358e+02
# 1      1960  8.837823e+01
# 2      1960  8.657098e+00
# 3      1960  7.972113e+01
# 4      1960  6.000000e+06
# ...     ...           ...
# 35302  2015  9.100000e+01
# 35303  2015  5.000000e+01
# 35304  2015  1.025000e+03
# 35305  2015  1.800000e+00
# 35306  2015  8.370000e+01
#
# [35307 rows x 6 columns]

# %%
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE CountryName = "Bangladesh";""",
           conn)
# Out:
#       CountryName CountryCode  \
# 0      Bangladesh         BGD
# 1      Bangladesh         BGD
# 2      Bangladesh         BGD
# 3      Bangladesh         BGD
# 4      Bangladesh         BGD
# ...           ...         ...
# 33381  Bangladesh         BGD
# 33382  Bangladesh         BGD
# 33383  Bangladesh         BGD
# 33384  Bangladesh         BGD
# 33385  Bangladesh         BGD
#
#                                            IndicatorName      IndicatorCode  \
# 0      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1      Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2      Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3      Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4                    Agriculture, value added (% of GDP)     NV.AGR.TOTL.ZS
# ...                                                  ...                ...
# 33381          Time required to register property (days)        IC.PRP.DURS
# 33382           Time required to start a business (days)        IC.REG.DURS
# 33383              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 33384                 Time to resolve insolvency (years)        IC.ISV.DURS
# 33385           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#        Year       Value
# 0      1960  204.001600
# 1      1960   80.296633
# 2      1960    4.839604
# 3      1960   75.457029
# 4      1960   57.474312
# ...     ...         ...
# 33381  2015  244.000000
# 33382  2015   19.500000
# 33383  2015  302.000000
# 33384  2015    4.000000
# 33385  2015   31.600000
#
# [33386 rows x 6 columns]

# %%
#Displaying CountryName and Value which belong to the country of Sweden
pd.read_sql("""SELECT CountryName, Value
               FROM Indicators
               WHERE CountryName = "Sweden";""",
           conn)
# Out:
#       CountryName       Value
# 0          Sweden   39.654400
# 1          Sweden   51.938251
# 2          Sweden   17.850733
# 3          Sweden   34.087518
# 4          Sweden   13.211098
# ...           ...         ...
# 26498      Sweden   14.000000
# 26499      Sweden    7.000000
# 26500      Sweden  122.000000
# 26501      Sweden    2.000000
# 26502      Sweden   49.100000
#
# [26503 rows x 2 columns]

# %%
#Information for the countries from the year of 2000
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Year = "2000";""",
           conn)
# Out:
#        CountryName CountryCode  \
# 0       Arab World         ARB
# 1       Arab World         ARB
# 2       Arab World         ARB
# 3       Arab World         ARB
# 4       Arab World         ARB
# ...            ...         ...
# 154723    Zimbabwe         ZWE
# 154724    Zimbabwe         ZWE
# 154725    Zimbabwe         ZWE
# 154726    Zimbabwe         ZWE
# 154727    Zimbabwe         ZWE
#
#                                             IndicatorName      IndicatorCode  \
# 0                 Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1       Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2       Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3              Access to non-solid fuel (% of population)     EG.NSF.ACCS.ZS
# 4       Adjusted net enrolment rate, primary, both sex...        SE.PRM.TENR
# ...                                                   ...                ...
# 154723                                   Urban population        SP.URB.TOTL
# 154724                      Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 154725                 Urban population growth (annual %)        SP.URB.GROW
# 154726               Use of IMF credit (DOD, current US$)     DT.DOD.DIMF.CD
# 154727  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#         Year         Value
# 0       2000  7.953695e+01
# 1       2000  6.586906e+01
# 2       2000  9.165462e+01
# 3       2000  8.156521e+01
# 4       2000  7.848897e+01
# ...      ...           ...
# 154723  2000  4.219744e+06
# 154724  2000  3.375800e+01
# 154725  2000  2.237783e+00
# 154726  2000  2.939490e+08
# 154727  2000  5.663196e+01
#
# [154728 rows x 6 columns]

# %%
#IndicatorName and IndicatorCode for the country that holds the CountryCode "ZWE"
pd.read_sql("""SELECT IndicatorName, IndicatorCode
               FROM Indicators
               WHERE CountryCode = "ZWE";""",
           conn)
# Out:
#                                            IndicatorName      IndicatorCode
# 0      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1      Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2      Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3      Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4            Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# ...                                                  ...                ...
# 29305          Time required to register property (days)        IC.PRP.DURS
# 29306           Time required to start a business (days)        IC.REG.DURS
# 29307              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 29308                 Time to resolve insolvency (years)        IC.ISV.DURS
# 29309           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
# [29310 rows x 2 columns]

# %%
pd.read_sql("""SELECT IndicatorName, IndicatorCode
               FROM Indicators
               WHERE CountryCode = "BGD";""",
           conn)
# Out:
#                                            IndicatorName      IndicatorCode
# 0      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1      Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2      Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3      Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4                    Agriculture, value added (% of GDP)     NV.AGR.TOTL.ZS
# ...                                                  ...                ...
# 33381          Time required to register property (days)        IC.PRP.DURS
# 33382           Time required to start a business (days)        IC.REG.DURS
# 33383              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 33384                 Time to resolve insolvency (years)        IC.ISV.DURS
# 33385           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
# [33386 rows x 2 columns]

# %%
#Values for Russian Federation since 1990
pd.read_sql("""SELECT Value
               FROM Indicators
               WHERE Year >=1990
               AND CountryName = "Russian Federation";""",
           conn)
# Out:
#             Value
# 0      100.000000
# 1      100.000000
# 2      100.000000
# 3       82.378718
# 4       24.388623
# ...           ...
# 15544   15.000000
# 15545   10.500000
# 15546  168.000000
# 15547    2.000000
# 15548   47.000000
#
# [15549 rows x 1 columns]

# %%
#Values for the United States between 1975 and 1986 inclusive
pd.read_sql("""SELECT Value
               FROM Indicators
               WHERE CountryName = "United States"
               AND Year>=1975 AND Year<=1986;""",
           conn)
# Out:
#              Value
# 0     8.073670e+01
# 1    -7.445968e-01
# 2     4.180197e+12
# 3     1.410010e+12
# 4    -1.718432e+00
# ...            ...
# 4325  1.125320e+00
# 4326  9.350000e+01
# 4327  9.110000e+01
# 4328  8.920000e+01
# 4329  5.422230e+01
#
# [4330 rows x 1 columns]

# %%
#Values for the Bangladesh between 1970 and 2006 inclusive
pd.read_sql("""SELECT Value
               FROM Indicators
               WHERE CountryName = "Bangladesh"
               AND Year>=1970 AND Year<=2006;""",
           conn)
# Out:
#               Value
# 0      5.040842e+01
# 1      3.386466e+01
# 2      6.621637e+01
# 3      6.779334e+08
# 4      0.000000e+00
# ...             ...
# 24488  2.751700e+01
# 24489  3.933591e+00
# 24490  5.473780e+08
# 24491  8.920000e+01
# 24492  2.475101e+01
#
# [24493 rows x 1 columns]

# %%
#All the details of Central African Republic and Rwanda after 1999
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Year >1999
               AND CountryName IN ('Central African Republic',
               'Rwanda');""",
           conn)
# Out:
#                     CountryName CountryCode  \
# 0      Central African Republic         CAF
# 1      Central African Republic         CAF
# 2      Central African Republic         CAF
# 3      Central African Republic         CAF
# 4      Central African Republic         CAF
# ...                         ...         ...
# 23592                    Rwanda         RWA
# 23593                    Rwanda         RWA
# 23594                    Rwanda         RWA
# 23595                    Rwanda         RWA
# 23596                    Rwanda         RWA
#
#                                            IndicatorName      IndicatorCode  \
# 0                Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1      Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2      Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3             Access to non-solid fuel (% of population)     EG.NSF.ACCS.ZS
# 4       Adjusted net national income (constant 2005 US$)     NY.ADJ.NNTY.KD
# ...                                                  ...                ...
# 23592          Time required to register property (days)        IC.PRP.DURS
# 23593           Time required to start a business (days)        IC.REG.DURS
# 23594              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 23595                 Time to resolve insolvency (years)        IC.ISV.DURS
# 23596           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#        Year         Value
# 0      2000  6.000000e+00
# 1      2000  7.000000e-01
# 2      2000  1.478114e+01
# 3      2000  2.492583e+00
# 4      2000  1.101137e+09
# ...     ...           ...
# 23592  2015  3.200000e+01
# 23593  2015  5.500000e+00
# 23594  2015  1.090000e+02
# 23595  2015  2.500000e+00
# 23596  2015  3.300000e+01
#
# [23597 rows x 6 columns]

# %%
#Information about GDP
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE IndicatorName LIKE 'GDP%';""",
           conn)
# Out:
#                                     CountryName CountryCode  \
# 0                        Caribbean small states         CSS
# 1                        Caribbean small states         CSS
# 2       East Asia & Pacific (all income levels)         EAS
# 3       East Asia & Pacific (all income levels)         EAS
# 4       East Asia & Pacific (all income levels)         EAS
# ...                                         ...         ...
# 138019                                 Zimbabwe         ZWE
# 138020                                 Zimbabwe         ZWE
# 138021                                 Zimbabwe         ZWE
# 138022                                 Zimbabwe         ZWE
# 138023                                 Zimbabwe         ZWE
#
#                                             IndicatorName      IndicatorCode  \
# 0                      GDP at market prices (current US$)     NY.GDP.MKTP.CD
# 1                            GDP per capita (current US$)     NY.GDP.PCAP.CD
# 2                GDP at market prices (constant 2005 US$)     NY.GDP.MKTP.KD
# 3                      GDP at market prices (current US$)     NY.GDP.MKTP.CD
# 4                      GDP per capita (constant 2005 US$)     NY.GDP.PCAP.KD
# ...                                                   ...                ...
# 138019  GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 138020      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 138021      GDP per person employed (constant 1990 PPP $)  SL.GDP.PCAP.EM.KD
# 138022           GDP, PPP (constant 2011 international $)  NY.GDP.MKTP.PP.KD
# 138023                 GDP, PPP (current international $)  NY.GDP.MKTP.PP.CD
#
#         Year         Value
# 0       1960  1.917148e+09
# 1       1960  4.574647e+02
# 2       1960  1.023739e+12
# 3       1960  1.530501e+11
# 4       1960  9.820268e+02
# ...      ...           ...
# 138019  2014  1.709144e+03
# 138020  2014  1.791514e+03
# 138021  2014  3.716000e+03
# 138022  2014  2.605736e+10
# 138023  2014  2.731316e+10
#
# [138024 rows x 6 columns]

# %%
#Details for Chile of 2010 and Peru of 2011 together
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE (CountryName = "Chile" AND Year=2010)
               UNION SELECT *
               FROM Indicators
               WHERE (CountryName = "Peru" AND Year=2011);""",
           conn)
# Out:
#      CountryName CountryCode  \
# 0          Chile         CHL
# 1          Chile         CHL
# 2          Chile         CHL
# 3          Chile         CHL
# 4          Chile         CHL
# ...          ...         ...
# 1937        Peru         PER
# 1938        Peru         PER
# 1939        Peru         PER
# 1940        Peru         PER
# 1941        Peru         PER
#
#                                           IndicatorName      IndicatorCode  \
# 0               Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1     Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2     Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3            Access to non-solid fuel (% of population)     EG.NSF.ACCS.ZS
# 4     Access to non-solid fuel, rural (% of rural po...  EG.NSF.ACCS.RU.ZS
# ...                                                 ...                ...
# 1937  Women who believe a husband is justified in be...     SG.VAW.BURN.ZS
# 1938  Women who believe a husband is justified in be...     SG.VAW.GOES.ZS
# 1939  Women who believe a husband is justified in be...     SG.VAW.NEGL.ZS
# 1940  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 1941  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#       Year      Value
# 0     2010  99.000000
# 1     2010  97.800000
# 2     2010  99.149194
# 3     2010  92.016859
# 4     2010  53.839147
# ...    ...        ...
# 1937  2011   1.000000
# 1938  2011   1.100000
# 1939  2011   2.300000
# 1940  2011   0.600000
# 1941  2011  30.365603
#
# [1942 rows x 6 columns]

# %%
#Showing information about the countries in the year 2015 except Arab World
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Year=2015
               AND CountryName NOT IN ('Arab World');""",
           conn)
# Out:
#                   CountryName CountryCode  \
# 0      Caribbean small states         CSS
# 1      Caribbean small states         CSS
# 2      Caribbean small states         CSS
# 3      Caribbean small states         CSS
# 4      Caribbean small states         CSS
# ...                       ...         ...
# 14712                Zimbabwe         ZWE
# 14713                Zimbabwe         ZWE
# 14714                Zimbabwe         ZWE
# 14715                Zimbabwe         ZWE
# 14716                Zimbabwe         ZWE
#
#                                            IndicatorName      IndicatorCode  \
# 0                               Bird species, threatened     EN.BIR.THRD.NO
# 1      Business extent of disclosure index (0=less di...     IC.BUS.DISC.XQ
# 2      Cost of business start-up procedures (% of GNI...  IC.REG.COST.PC.ZS
# 3      Depth of credit information index (0=low to 8=...     IC.CRD.INFO.XQ
# 4      Distance to frontier score (0=lowest performan...     IC.BUS.DFRN.XQ
# ...                                                  ...                ...
# 14712          Time required to register property (days)        IC.PRP.DURS
# 14713           Time required to start a business (days)        IC.REG.DURS
# 14714              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 14715                 Time to resolve insolvency (years)        IC.ISV.DURS
# 14716           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#        Year       Value
# 0      2015   66.000000
# 1      2015    3.461538
# 2      2015   20.353846
# 3      2015    1.000000
# 4      2015   58.045385
# ...     ...         ...
# 14712  2015   36.000000
# 14713  2015   90.000000
# 14714  2015  242.000000
# 14715  2015    3.300000
# 14716  2015   32.800000
#
# [14717 rows x 6 columns]

# %%
#IndicatorName for the countries not started with the letter 'P' and arranged the list as the most recent comes first, then by name in order
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE CountryName NOT LIKE 'P%'
               ORDER BY YEAR DESC, IndicatorName;""",
           conn)
# Out:
#                       CountryName CountryCode  \
# 0                          Bhutan         BTN
# 1              West Bank and Gaza         WBG
# 2                      Uzbekistan         UZB
# 3                   United States         USA
# 4                         Ukraine         UKR
# ...                           ...         ...
# 5373692  Central African Republic         CAF
# 5373693                    Canada         CAN
# 5373694                    Brazil         BRA
# 5373695                   Austria         AUT
# 5373696                 Australia         AUS
#
#                                              IndicatorName   IndicatorCode  \
# 0        Average time to clear exports through customs ...  IC.CUS.DURS.EX
# 1                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 2                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 3                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 4                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# ...                                                    ...             ...
# 5373692                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373693                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373694                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373695                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373696                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
#
#          Year         Value
# 0        2015  1.270000e+01
# 1        2015  9.674752e+00
# 2        2015  1.129908e+01
# 3        2015  1.162816e+01
# 4        2015  7.642274e+00
# ...       ...           ...
# 5373692  1960  7.526927e+00
# 5373693  1960  1.639533e+01
# 5373694  1960  2.448357e-13
# 5373695  1960  3.090663e+01
# 5373696  1960  1.069203e+01
#
# [5373697 rows x 6 columns]

# %%
#Countries with the Value between 100 and 500
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Value BETWEEN 100 AND 500;""",
           conn)
# Out:
#        CountryName CountryCode  \
# 0       Arab World         ARB
# 1       Arab World         ARB
# 2       Arab World         ARB
# 3       Arab World         ARB
# 4       Arab World         ARB
# ...            ...         ...
# 201685    Zimbabwe         ZWE
# 201686    Zimbabwe         ZWE
# 201687    Zimbabwe         ZWE
# 201688    Zimbabwe         ZWE
# 201689    Zimbabwe         ZWE
#
#                                             IndicatorName   IndicatorCode  \
# 0       Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1       Mortality rate, adult, female (per 1,000 femal...  SP.DYN.AMRT.FE
# 2       Mortality rate, adult, male (per 1,000 male ad...  SP.DYN.AMRT.MA
# 3          Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN
# 4                     Mortality rate, under-5 (per 1,000)     SH.DYN.MORT
# ...                                                   ...             ...
# 201685  Maternal mortality ratio (modeled estimate, pe...     SH.STA.MMRT
# 201686          Time required to build a warehouse (days)     IC.WRH.DURS
# 201687         Time required to enforce a contract (days)     IC.LGL.DURS
# 201688            Time required to get electricity (days)     IC.ELC.TIME
# 201689              Time to prepare and pay taxes (hours)     IC.TAX.DURS
#
#         Year       Value
# 0       1960  133.560907
# 1       1960  298.935703
# 2       1960  357.705584
# 3       1960  159.950234
# 4       1960  249.360225
# ...      ...         ...
# 201685  2015  443.000000
# 201686  2015  448.000000
# 201687  2015  410.000000
# 201688  2015  106.000000
# 201689  2015  242.000000
#
# [201690 rows x 6 columns]

# %% [markdown]
# # SQL Aggregate Functions

# %%
#Calculating the average value of urban population
pd.read_sql("""SELECT AVG(Value)
               FROM Indicators
               WHERE IndicatorName = 'Urban population';""",
           conn)
# Out:
#      AVG(Value)
# 0  6.240680e+07

# %%
#The lowest GDP per capita in 2013
pd.read_sql("""SELECT CountryName, MIN (Value)
               FROM Indicators
               WHERE IndicatorName = 'GDP per capita (current US$)'
               AND Year = 2013;""",
            conn)
# Out:
#   CountryName  MIN (Value)
# 0      Malawi   239.869731

# %%
#Country Name and Country Code
pd.read_sql("""SELECT CountryName as "Country Name", CountryCode as "Country Code"
               FROM Indicators;""",
            conn)
# Out:
#         Country Name Country Code
# 0         Arab World          ARB
# 1         Arab World          ARB
# 2         Arab World          ARB
# 3         Arab World          ARB
# 4         Arab World          ARB
# ...              ...          ...
# 5656453     Zimbabwe          ZWE
# 5656454     Zimbabwe          ZWE
# 5656455     Zimbabwe          ZWE
# 5656456     Zimbabwe          ZWE
# 5656457     Zimbabwe          ZWE
#
# [5656458 rows x 2 columns]

# %%
#Displaying the countries with the highest GDP per capita in 2009
pd.read_sql("""SELECT * 
               FROM Indicators
               WHERE IndicatorName='GDP per capita (current US$)'
               AND Year= 2009
               ORDER BY Value DESC
               LIMIT 10;""",
           conn)
# Out:
#      CountryName CountryCode                 IndicatorName   IndicatorCode  \
# 0         Monaco         MCO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Liechtenstein         LIE  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2     Luxembourg         LUX  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3        Bermuda         BMU  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4         Norway         NOR  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 5    Switzerland         CHE  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 6          Qatar         QAT  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 7        Denmark         DNK  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 8    Netherlands         NLD  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 9        Ireland         IRL  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#    Year          Value
# 0  2009  152877.365748
# 1  2009  125107.671090
# 2  2009  101221.810003
# 3  2009   88463.312816
# 4  2009   80017.776810
# 5  2009   69672.004715
# 6  2009   61463.903582
# 7  2009   57895.501225
# 8  2009   51900.340095
# 9  2009   51900.267139

# %%
#Comparing Life expectancy at birth max values for Russian Federation, Bolivia, United States, Nigeria and India from 2012 inclusive
pd.read_sql(""" SELECT CountryName, MAX(Value)
                FROM Indicators
                WHERE IndicatorName= 'Life expectancy at birth, total (years)'
                AND CountryName IN ('Russian Federation', 'Bolivia',
                'United States', 'Nigeria', 'India')
                AND Year>=2012
                GROUP BY CountryName;""",
           conn)
# Out:
#           CountryName  MAX(Value)
# 0             Bolivia   67.913439
# 1               India   67.660415
# 2             Nigeria   52.442146
# 3  Russian Federation   71.073171
# 4       United States   78.841463

# %%
#Death rate in Latin America
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE IndicatorName='Death rate, crude (per 1,000 people)'
               AND CountryName LIKE 'Latin America%'
               ORDER BY Value ASC;""",
           conn)
# Out:
#                                        CountryName CountryCode  \
# 0      Latin America & Caribbean (developing only)         LAC
# 1      Latin America & Caribbean (developing only)         LAC
# 2      Latin America & Caribbean (developing only)         LAC
# 3      Latin America & Caribbean (developing only)         LAC
# 4      Latin America & Caribbean (developing only)         LAC
# ..                                             ...         ...
# 103    Latin America & Caribbean (developing only)         LAC
# 104  Latin America & Caribbean (all income levels)         LCN
# 105    Latin America & Caribbean (developing only)         LAC
# 106    Latin America & Caribbean (developing only)         LAC
# 107    Latin America & Caribbean (developing only)         LAC
#
#                             IndicatorName   IndicatorCode  Year      Value
# 0    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2006   5.641006
# 1    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2005   5.643475
# 2    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2007   5.644845
# 3    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2008   5.650285
# 4    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2004   5.655212
# ..                                    ...             ...   ...        ...
# 103  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1963  12.801260
# 104  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1960  13.012060
# 105  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1962  13.139747
# 106  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1961  13.486745
# 107  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1960  13.843268
#
# [108 rows x 6 columns]

# %%
#Null values
pd.read_sql("""SELECT COUNT(*)
               FROM Indicators
               WHERE IndicatorName IS NULL;""",
           conn)
# Out:
#    COUNT(*)
# 0         0

# %%
#The sum of hospital beds
pd.read_sql("""SELECT SUM(Value)
               FROM Indicators
               WHERE IndicatorName = 'Hospital beds (per 1,000 people)';""",
           conn)
# Out:
#      SUM(Value)
# 0  16329.169032

# %% [markdown]
# # SQL Join

# %%
#Fertility rate in Bolivia
pd.read_sql(""" SELECT Indicators.*, Series.LongDefinition
                FROM Indicators
                LEFT JOIN Series 
                ON Indicators.IndicatorName  = Series.IndicatorName
                WHERE Indicators.IndicatorName LIKE 'Fertility rate%'
                AND CountryName ='Bolivia';""",
            conn)
# Out:
#    CountryName CountryCode                             IndicatorName  \
# 0      Bolivia         BOL  Fertility rate, total (births per woman)
# 1      Bolivia         BOL  Fertility rate, total (births per woman)
# 2      Bolivia         BOL  Fertility rate, total (births per woman)
# 3      Bolivia         BOL  Fertility rate, total (births per woman)
# 4      Bolivia         BOL  Fertility rate, total (births per woman)
# 5      Bolivia         BOL  Fertility rate, total (births per woman)
# 6      Bolivia         BOL  Fertility rate, total (births per woman)
# 7      Bolivia         BOL  Fertility rate, total (births per woman)
# 8      Bolivia         BOL  Fertility rate, total (births per woman)
# 9      Bolivia         BOL  Fertility rate, total (births per woman)
# 10     Bolivia         BOL  Fertility rate, total (births per woman)
# 11     Bolivia         BOL  Fertility rate, total (births per woman)
# 12     Bolivia         BOL  Fertility rate, total (births per woman)
# 13     Bolivia         BOL  Fertility rate, total (births per woman)
# 14     Bolivia         BOL  Fertility rate, total (births per woman)
# 15     Bolivia         BOL  Fertility rate, total (births per woman)
# 16     Bolivia         BOL  Fertility rate, total (births per woman)
# 17     Bolivia         BOL  Fertility rate, total (births per woman)
# 18     Bolivia         BOL  Fertility rate, total (births per woman)
# 19     Bolivia         BOL  Fertility rate, total (births per woman)
# 20     Bolivia         BOL  Fertility rate, total (births per woman)
# 21     Bolivia         BOL  Fertility rate, total (births per woman)
# 22     Bolivia         BOL  Fertility rate, total (births per woman)
# 23     Bolivia         BOL  Fertility rate, total (births per woman)
# 24     Bolivia         BOL  Fertility rate, total (births per woman)
# 25     Bolivia         BOL  Fertility rate, total (births per woman)
# 26     Bolivia         BOL  Fertility rate, total (births per woman)
# 27     Bolivia         BOL  Fertility rate, total (births per woman)
# 28     Bolivia         BOL  Fertility rate, total (births per woman)
# 29     Bolivia         BOL  Fertility rate, total (births per woman)
# 30     Bolivia         BOL  Fertility rate, total (births per woman)
# 31     Bolivia         BOL  Fertility rate, total (births per woman)
# 32     Bolivia         BOL  Fertility rate, total (births per woman)
# 33     Bolivia         BOL  Fertility rate, total (births per woman)
# 34     Bolivia         BOL  Fertility rate, total (births per woman)
# 35     Bolivia         BOL  Fertility rate, total (births per woman)
# 36     Bolivia         BOL  Fertility rate, total (births per woman)
# 37     Bolivia         BOL  Fertility rate, total (births per woman)
# 38     Bolivia         BOL  Fertility rate, total (births per woman)
# 39     Bolivia         BOL  Fertility rate, total (births per woman)
# 40     Bolivia         BOL  Fertility rate, total (births per woman)
# 41     Bolivia         BOL  Fertility rate, total (births per woman)
# 42     Bolivia         BOL  Fertility rate, total (births per woman)
# 43     Bolivia         BOL  Fertility rate, total (births per woman)
# 44     Bolivia         BOL  Fertility rate, total (births per woman)
# 45     Bolivia         BOL  Fertility rate, total (births per woman)
# 46     Bolivia         BOL  Fertility rate, total (births per woman)
# 47     Bolivia         BOL  Fertility rate, total (births per woman)
# 48     Bolivia         BOL  Fertility rate, total (births per woman)
# 49     Bolivia         BOL  Fertility rate, total (births per woman)
# 50     Bolivia         BOL  Fertility rate, total (births per woman)
# 51     Bolivia         BOL  Fertility rate, total (births per woman)
# 52     Bolivia         BOL  Fertility rate, total (births per woman)
# 53     Bolivia         BOL  Fertility rate, total (births per woman)
#
#      IndicatorCode  Year  Value  \
# 0   SP.DYN.TFRT.IN  1960  6.700
# 1   SP.DYN.TFRT.IN  1961  6.668
# 2   SP.DYN.TFRT.IN  1962  6.633
# 3   SP.DYN.TFRT.IN  1963  6.597
# 4   SP.DYN.TFRT.IN  1964  6.559
# 5   SP.DYN.TFRT.IN  1965  6.519
# 6   SP.DYN.TFRT.IN  1966  6.477
# 7   SP.DYN.TFRT.IN  1967  6.432
# 8   SP.DYN.TFRT.IN  1968  6.384
# 9   SP.DYN.TFRT.IN  1969  6.335
# 10  SP.DYN.TFRT.IN  1970  6.284
# 11  SP.DYN.TFRT.IN  1971  6.233
# 12  SP.DYN.TFRT.IN  1972  6.182
# 13  SP.DYN.TFRT.IN  1973  6.132
# 14  SP.DYN.TFRT.IN  1974  6.081
# 15  SP.DYN.TFRT.IN  1975  6.029
# 16  SP.DYN.TFRT.IN  1976  5.975
# 17  SP.DYN.TFRT.IN  1977  5.917
# 18  SP.DYN.TFRT.IN  1978  5.855
# 19  SP.DYN.TFRT.IN  1979  5.787
# 20  SP.DYN.TFRT.IN  1980  5.715
# 21  SP.DYN.TFRT.IN  1981  5.637
# 22  SP.DYN.TFRT.IN  1982  5.556
# 23  SP.DYN.TFRT.IN  1983  5.472
# 24  SP.DYN.TFRT.IN  1984  5.386
# 25  SP.DYN.TFRT.IN  1985  5.300
# 26  SP.DYN.TFRT.IN  1986  5.215
# 27  SP.DYN.TFRT.IN  1987  5.132
# 28  SP.DYN.TFRT.IN  1988  5.051
# 29  SP.DYN.TFRT.IN  1989  4.971
# 30  SP.DYN.TFRT.IN  1990  4.894
# 31  SP.DYN.TFRT.IN  1991  4.817
# 32  SP.DYN.TFRT.IN  1992  4.741
# 33  SP.DYN.TFRT.IN  1993  4.664
# 34  SP.DYN.TFRT.IN  1994  4.585
# 35  SP.DYN.TFRT.IN  1995  4.503
# 36  SP.DYN.TFRT.IN  1996  4.418
# 37  SP.DYN.TFRT.IN  1997  4.331
# 38  SP.DYN.TFRT.IN  1998  4.241
# 39  SP.DYN.TFRT.IN  1999  4.148
# 40  SP.DYN.TFRT.IN  2000  4.055
# 41  SP.DYN.TFRT.IN  2001  3.960
# 42  SP.DYN.TFRT.IN  2002  3.866
# 43  SP.DYN.TFRT.IN  2003  3.773
# 44  SP.DYN.TFRT.IN  2004  3.683
# 45  SP.DYN.TFRT.IN  2005  3.595
# 46  SP.DYN.TFRT.IN  2006  3.510
# 47  SP.DYN.TFRT.IN  2007  3.427
# 48  SP.DYN.TFRT.IN  2008  3.348
# 49  SP.DYN.TFRT.IN  2009  3.271
# 50  SP.DYN.TFRT.IN  2010  3.200
# 51  SP.DYN.TFRT.IN  2011  3.133
# 52  SP.DYN.TFRT.IN  2012  3.073
# 53  SP.DYN.TFRT.IN  2013  3.017
#
#                                        LongDefinition
# 0   Total fertility rate represents the number of ...
# 1   Total fertility rate represents the number of ...
# 2   Total fertility rate represents the number of ...
# 3   Total fertility rate represents the number of ...
# 4   Total fertility rate represents the number of ...
# 5   Total fertility rate represents the number of ...
# 6   Total fertility rate represents the number of ...
# 7   Total fertility rate represents the number of ...
# 8   Total fertility rate represents the number of ...
# 9   Total fertility rate represents the number of ...
# 10  Total fertility rate represents the number of ...
# 11  Total fertility rate represents the number of ...
# 12  Total fertility rate represents the number of ...
# 13  Total fertility rate represents the number of ...
# 14  Total fertility rate represents the number of ...
# 15  Total fertility rate represents the number of ...
# 16  Total fertility rate represents the number of ...
# 17  Total fertility rate represents the number of ...
# 18  Total fertility rate represents the number of ...
# 19  Total fertility rate represents the number of ...
# 20  Total fertility rate represents the number of ...
# 21  Total fertility rate represents the number of ...
# 22  Total fertility rate represents the number of ...
# 23  Total fertility rate represents the number of ...
# 24  Total fertility rate represents the number of ...
# 25  Total fertility rate represents the number of ...
# 26  Total fertility rate represents the number of ...
# 27  Total fertility rate represents the number of ...
# 28  Total fertility rate represents the number of ...
# 29  Total fertility rate represents the number of ...
# 30  Total fertility rate represents the number of ...
# 31  Total fertility rate represents the number of ...
# 32  Total fertility rate represents the number of ...
# 33  Total fertility rate represents the number of ...
# 34  Total fertility rate represents the number of ...
# 35  Total fertility rate represents the number of ...
# 36  Total fertility rate represents the number of ...
# 37  Total fertility rate represents the number of ...
# 38  Total fertility rate represents the number of ...
# 39  Total fertility rate represents the number of ...
# 40  Total fertility rate represents the number of ...
# 41  Total fertility rate represents the number of ...
# 42  Total fertility rate represents the number of ...
# 43  Total fertility rate represents the number of ...
# 44  Total fertility rate represents the number of ...
# 45  Total fertility rate represents the number of ...
# 46  Total fertility rate represents the number of ...
# 47  Total fertility rate represents the number of ...
# 48  Total fertility rate represents the number of ...
# 49  Total fertility rate represents the number of ...
# 50  Total fertility rate represents the number of ...
# 51  Total fertility rate represents the number of ...
# 52  Total fertility rate represents the number of ...
# 53  Total fertility rate represents the number of ...

# %%
#CO2 emissions in the world
pd.read_sql(""" SELECT Indicators.*, Series.LongDefinition
                FROM Indicators
                LEFT JOIN Series 
                ON Indicators.IndicatorName  = Series.IndicatorName
                WHERE Indicators.IndicatorName LIKE 'CO2%'
                AND CountryName ='World'
                ORDER BY Year DESC
                LIMIT 10;""",
            conn)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0       World         WLD  CO2 emissions from transport (% of total fuel ...
# 1       World         WLD  CO2 emissions from residential buildings and c...
# 2       World         WLD  CO2 emissions from other sectors, excluding re...
# 3       World         WLD  CO2 emissions from manufacturing industries an...
# 4       World         WLD  CO2 emissions from electricity and heat produc...
# 5       World         WLD  CO2 intensity (kg per kg of oil equivalent ene...
# 6       World         WLD  CO2 emissions from transport (% of total fuel ...
# 7       World         WLD     CO2 emissions from solid fuel consumption (kt)
# 8       World         WLD  CO2 emissions from solid fuel consumption (% o...
# 9       World         WLD  CO2 emissions from residential buildings and c...
#
#        IndicatorCode  Year         Value  \
# 0     EN.CO2.TRAN.ZS  2012  1.987419e+01
# 1     EN.CO2.BLDG.ZS  2012  8.516604e+00
# 2     EN.CO2.OTHX.ZS  2012  1.877231e+00
# 3     EN.CO2.MANF.ZS  2012  2.107766e+01
# 4     EN.CO2.ETOT.ZS  2012  4.865408e+01
# 5  EN.ATM.CO2E.EG.ZS  2011  2.596009e+00
# 6     EN.CO2.TRAN.ZS  2011  1.972732e+01
# 7  EN.ATM.CO2E.SF.KT  2011  6.453920e+06
# 8  EN.ATM.CO2E.SF.ZS  2011  1.862631e+01
# 9     EN.CO2.BLDG.ZS  2011  8.692554e+00
#
#                                       LongDefinition
# 0  CO2 emissions from transport contains emission...
# 1  CO2 emissions from residential buildings and c...
# 2  CO2 emissions from other sectors, less residen...
# 3  CO2 emissions from manufacturing industries an...
# 4  CO2 emissions from electricity and heat produc...
# 5  Carbon dioxide emissions from solid fuel consu...
# 6  CO2 emissions from transport contains emission...
# 7  Carbon dioxide emissions from solid fuel consu...
# 8  Carbon dioxide emissions from solid fuel consu...
# 9  CO2 emissions from residential buildings and c...

# %% [markdown]
# # Hope, this is useful! :)
